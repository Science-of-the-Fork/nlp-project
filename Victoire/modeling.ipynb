# %% [markdown]
# # Pre-processing

# %%
from pprint import pprint
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import unicodedata

import matplotlib.pyplot as plt
import seaborn as sns

import unicodedata
import nltk
from nltk.tokenize.toktok import ToktokTokenizer
from nltk.corpus import stopwords

import time
import acquire #basic_clean, lemmatize
# np.random.seed("123")

# %% [markdown]
# **get data**

# %%
python_df = acquire.get_data(1)
# time.sleep(30)
java_sc_df = acquire.get_data(2)

# %%
python_df.head(2)

# %%
java_sc_df.head(2)

# %%
def clean(string):
    """
    This function puts a string in lowercase, normalizes any unicode characters, removes anything that         
    isn't an alphanumeric symbol or single quote.
    """
    # Normalize unicode characters
    string = unicodedata.normalize('NFKD', string)\
    .encode('ascii', 'ignore')\
    .decode('utf-8', 'ignore')
    
    # Remove unwanted characters and put string in lowercase
    string = re.sub(r"[^\w0-9'\s]", '', string).lower()
            
    return string

# %%
# cleaned_row = []
# for i in df.readme_content.values:
#     cleaned_row.append(clean(i))
# df = df.assign(cleaned_content=cleaned_row)

# %%
# clean the content separated my language as on big string
python_words = clean(" ".join(python_df.readme_content)).split()
javaScript_words = clean(" ".join(java_sc_df.readme_content)).split()
# make a data frame of the words
words_py = pd.DataFrame(python_words, columns=["python_words"])
words_js = pd.DataFrame(javaScript_words, columns=["javascript_words"])

# %%
words_js

# %%
words_py

# %% [markdown]
# ## Term Frequency (TF)

# %%
# the count of the number of occurances of each word.
py_word_df = pd.DataFrame(words_py.python_words.value_counts().index, columns=["word"]).assign(raw_count_py= words_py.python_words.value_counts().values)
js_word_df = pd.DataFrame(words_js.javascript_words.value_counts().index, columns=["word"]).assign(raw_count_js= words_js.javascript_words.value_counts().values)

# The number of times each word appears divided by the total number of words.
frequency_py = py_word_df.raw_count_py / len(words_py)
frequency_js = js_word_df.raw_count_js / len(words_js)

# The frequency of each word divided by the maximum frequency. 
augmented_frequency_py = frequency_py / frequency_py.max()
augmented_frequency_js = frequency_js / frequency_js.max()

# add to the dataframe
py_word_df["frequency_py"] = frequency_py
py_word_df["augmented_frequency_py"] = augmented_frequency_py
js_word_df["frequency_js"] = frequency_js
js_word_df["augmented_frequency_js"] = augmented_frequency_js

# %%
py_word_df.head()

# %%
js_word_df.head()

# %% [markdown]
# ## Inverse Document Frequency (IDF)

# %%
python_df.head(2), java_sc_df.head(2)

# %%
def prep_data(text:str, more_stopwords=[]):
    'A simple function to cleanup text data'
    wnl = nltk.stem.WordNetLemmatizer() # lemmitizer object
    # add more stop words to the original dictionary stop words from the english language
    stopwords = nltk.corpus.stopwords.words('english') + more_stopwords
    # normalize the string
    text = (unicodedata.normalize('NFKD', text).encode('ascii', 'ignore').decode('utf-8', 'ignore').lower())
    # remove not letters of numbers
    words = re.sub(r'[^\w\s]', '', text).split()
    # lemmatize the string
    lemma =  [wnl.lemmatize(word) for word in words if word not in stopwords]
    return lemma

# %%
# our 3 example documents
documents = {
    'python': " ".join(python_df.readme_content),
    'javaScript': " ".join(java_sc_df.readme_content),
}

for doc, topic in documents.items():
    # clean and lemmatize the data and join them back by space
    documents[doc] = " ".join(prep_data(topic))
    print('Cleaning and lemmatizing...')

# %%
# A simple way to calculate idf for demonstration. Note that this
# function relies on the globally defined documents variable.
def idf(word):            
    n_occurences = sum([1 for doc in documents.values() if word in doc])
    return len(documents) / n_occurences + 1

# Get a list of the unique words
unique_words = pd.Series(' '.join(documents.values()).split()).unique()

# put the unique words into a data frame
(pd.DataFrame(dict(word=unique_words))
 # calculate the idf for each word
 .assign(idf=lambda df: df.word.apply(idf))
 # sort the data for presentation purposes
 .set_index('word')
 .sort_values(by='idf', ascending=False)
 .head(5))

# %%
def prep_readmes(df, col="readme_content"):
    """
    Takes in the dataframe and the column name that contains the corpus data, creates a column of cleaned data, then uses that 
    to create a column without stopwords that is lemmatized, performs a train-validate-test split, performs an x-y split, and
    returns x and y train, x and y validate, and x and y test.
    """
    # Create the cleaned column

    cleaned_row = []
    for i in df.readme_content.values:
        cleaned_row.append(clean(i))
    df = df.assign(cleaned_content=cleaned_row)
#     df['cleaned'] = df[col].apply(lambda x: clean(x))
    df['lemmatized'] = df['cleaned_content'].apply(lambda x: lemmatize(remove_stopwords(x)))
    
    # Split the dataframe (70/15/15)
    train, validate, test = split_readmes(df)
    
#     # perform x-y split
#     x_train, y_train = train.drop(columns=('language')), train.language
#     x_validate, y_validate = validate.drop(columns=('language')), validate.language
#     x_test, y_test = test.drop(columns=('language')), test.language
    
    return train, validate, test

# %%
acquire_readmes()

# %%
import wrangle

# %%
train, validate, test = wrangle.prep_readmes(python_df)

# %%
train

# %%
python_df = acquire.get_data(1)
# time.sleep(30)
java_sc_df = acquire.get_data(2)

# %%
df = pd.concat([python_df, java_sc_df],axis=0)
df
# Out:
#     Unnamed: 0                                          repo_name  \
# 0            0                          jackfrued/Python-100-Days
# 1            1                   donnemartin/system-design-primer
# 2            2                      Significant-Gravitas/Auto-GPT
# 3            3               AUTOMATIC1111/stable-diffusion-webui
# 4            4             yandex-praktikum/backend_test_homework
# ..         ...                                                ...
# 83          83  learn-co-students/javascript-strings-lab-js-ap...
# 84          84                              openlayers/openlayers
# 85          85  learn-co-curriculum/phase-1-destructuring-assi...
# 86          86                                  airbnb/lottie-web
# 87          87        bloominstituteoftechnology/node-db3-project
#
#                                                   url    language  \
# 0   https://github.com/jackfrued/Python-100-Days/b...      Python
# 1   https://github.com/donnemartin/system-design-p...      Python
# 2   https://github.com/Significant-Gravitas/Auto-G...      Python
# 3   https://github.com/AUTOMATIC1111/stable-diffus...      Python
# 4   https://github.com/yandex-praktikum/backend_te...      Python
# ..                                                ...         ...
# 83  https://github.com/learn-co-students/javascrip...  JavaScript
# 84  https://github.com/openlayers/openlayers/blob/...  JavaScript
# 85  https://github.com/learn-co-curriculum/phase-1...  JavaScript
# 86  https://github.com/airbnb/lottie-web/blob/mast...  JavaScript
# 87  https://github.com/bloominstituteoftechnology/...  JavaScript
#
#                                        readme_content
# 0   Python - 100天从新手到大师作者：骆昊说明：从项目上线到获得8w+星标以来，一直收...
# 1   English ∙ 日本語 ∙ 简体中文 ∙ 繁體中文 | العَرَبِيَّة‎ ∙ ...
# 2   Auto-GPT: An Autonomous GPT-4 Experiment💡 Get ...
# 3   Stable Diffusion web UIA browser interface bas...
# 4                               backend_test_homework
# ..                                                ...
# 83  JavaScript Strings LabOverviewIn this lab, we'...
# 84  OpenLayersOpenLayers is a high-performance, fe...
# 85  Destructuring AssignmentLearning GoalsUse dest...
# 86  Lottie for Web, Android, iOS, React Native, an...
# 87  Node DB3 Project Starter CodeTask 1: Project S...
#
# [178 rows x 5 columns]

# %%
df.to_csv("full_py_and_js_data.csv", mode="w")

# %%
import wrangle

# %%
wrangle.acquire_readmes()
# Out:
# returning python and Java-script data
#     Unnamed: 0                                     repo_name  \
# 0            0                     jackfrued/Python-100-Days
# 1            1              donnemartin/system-design-primer
# 2            2                 Significant-Gravitas/Auto-GPT
# 3            3          AUTOMATIC1111/stable-diffusion-webui
# 4            4        yandex-praktikum/backend_test_homework
# ..         ...                                           ...
# 85          85  Ebazhanov/linkedin-skill-assessments-quizzes
# 86          86                           apachecn/ailearning
# 87          87                                  hankcs/HanLP
# 88          88                        langchain-ai/langchain
# 89          89                                 XX-net/XX-Net
#
#                                                   url language  \
# 0   https://github.com/jackfrued/Python-100-Days/b...   Python
# 1   https://github.com/donnemartin/system-design-p...   Python
# 2   https://github.com/Significant-Gravitas/Auto-G...   Python
# 3   https://github.com/AUTOMATIC1111/stable-diffus...   Python
# 4   https://github.com/yandex-praktikum/backend_te...   Python
# ..                                                ...      ...
# 85  https://github.com/Ebazhanov/linkedin-skill-as...   Python
# 86  https://github.com/apachecn/ailearning/blob/ma...   Python
# 87  https://github.com/hankcs/HanLP/blob/doc-zh/RE...   Python
# 88  https://github.com/langchain-ai/langchain/blob...   Python
# 89  https://github.com/XX-net/XX-Net/blob/master/R...   Python
#
#                                        readme_content  Unnamed: 0  \
# 0   Python - 100天从新手到大师作者：骆昊说明：从项目上线到获得8w+星标以来，一直收...         0.0
# 1   English ∙ 日本語 ∙ 简体中文 ∙ 繁體中文 | العَرَبِيَّة‎ ∙ ...         1.0
# 2   Auto-GPT: An Autonomous GPT-4 Experiment💡 Get ...         2.0
# 3   Stable Diffusion web UIA browser interface bas...         3.0
# 4                               backend_test_homework         4.0
# ..                                                ...         ...
# 85  Linkedin Skill assessments - Answers⚠️ DISCLAI...        85.0
# 86                                  AI learning协议：...        86.0
# 87  HanLP: Han Language Processing                ...        87.0
# 88  🦜️🔗 LangChain⚡ Building applications with LLMs...         NaN
# 89  🚀 XX-Net (翻墙VPN)这是一个可靠的翻墙系统，已经连续运行 8 年！我们不去研究墙...         NaN
#
#                                             repo_name  \
# 0                       nightscout/cgm-remote-monitor
# 1                      trekhleb/javascript-algorithms
# 2                                  angular/angular.js
# 3                 TheOdinProject/javascript-exercises
# 4                                       jquery/jquery
# ..                                                ...
# 85  learn-co-curriculum/phase-1-destructuring-assi...
# 86                                  airbnb/lottie-web
# 87        bloominstituteoftechnology/node-db3-project
# 88                                                NaN
# 89                                                NaN
#
#                                                   url    language  \
# 0   https://github.com/nightscout/cgm-remote-monit...  JavaScript
# 1   https://github.com/trekhleb/javascript-algorit...  JavaScript
# 2   https://github.com/angular/angular.js/blob/mas...  JavaScript
# 3   https://github.com/TheOdinProject/javascript-e...  JavaScript
# 4   https://github.com/jquery/jquery/blob/main/REA...  JavaScript
# ..                                                ...         ...
# 85  https://github.com/learn-co-curriculum/phase-1...  JavaScript
# 86  https://github.com/airbnb/lottie-web/blob/mast...  JavaScript
# 87  https://github.com/bloominstituteoftechnology/...  JavaScript
# 88                                                NaN         NaN
# 89                                                NaN         NaN
#
#                                        readme_content
# 0   Nightscout Web Monitor (a.k.a. cgm-remote-moni...
# 1   جافا سكريبت خوارزميات  وهياكل البياناتتحتوي هذ...
# 2   Using AngularJS with the Closure CompilerThe C...
# 3   JavaScript ExercisesThese JavaScript exercises...
# 4   jQuery — New Wave JavaScriptMeetings are curre...
# ..                                                ...
# 85  Destructuring AssignmentLearning GoalsUse dest...
# 86  Lottie for Web, Android, iOS, React Native, an...
# 87  Node DB3 Project Starter CodeTask 1: Project S...
# 88                                                NaN
# 89                                                NaN
#
# [90 rows x 10 columns]
